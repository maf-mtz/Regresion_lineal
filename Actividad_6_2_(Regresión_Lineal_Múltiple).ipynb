# %% [markdown]
# <a href="https://colab.research.google.com/github/maf-mtz/Regresion_lineal/blob/main/Actividad_6_2_(Regresi%C3%B3n_Lineal_M%C3%BAltiple).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Actividad 6.2 (Regresión Lineal Múltiple)
#
# Amairany Rodríguez | A01702927
#
# Maria Fernanda Martínez | A01067198
#
# Jose Ignacio Hernandez | A01703130
#
# Leonardo Isaias Guevara | A01275327

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# declaramos nuestros dataframes
dfmex=pd.read_csv("dfmex SIN NULOS.csv")

# %%
dfmex['host_acceptance_rate'] = dfmex['host_acceptance_rate'].str.replace('%', '')
dfmex['host_acceptance_rate'] = dfmex['host_acceptance_rate'].str.replace('sin información', '0')

# %%
dfmex['host_response_rate'] = dfmex['host_response_rate'].str.replace('%', '')
dfmex['host_response_rate'] = dfmex['host_response_rate'].str.replace('sin información', '0')

# %%
dfmex['price'] = dfmex['price'].str.replace('$', '')
dfmex['price'] = dfmex['price'].str.replace(',', '')
# Out:
# <ipython-input-143-237433df7990>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dfmex['price'] = dfmex['price'].str.replace('$', '')

# %% [markdown]
# ## DF mex

# %%
fprivate = dfmex['room_type'].str.contains('Private room')
df_filtrado1 = dfmex[fprivate]

fhotel = dfmex['room_type'].str.contains('Hotel room')
df_filtrado2 = dfmex[fprivate]

# %% [markdown]
# ###"host_acceptance_rate vs host_response_rate, Price, number_of_reviews , review_scores_rating” F1

# %%
from turtle import color
sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=df_filtrado1)
sns.scatterplot(x='price', y='host_acceptance_rate', color="red", data=df_filtrado1)
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="yellow", data=df_filtrado1)
sns.scatterplot(x='review_scores_rating', y='host_acceptance_rate', color="green", data=df_filtrado1)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df_filtrado1[["host_response_rate", "price", "number_of_reviews" , "review_scores_rating"]]
Var_Dep= df_filtrado1['host_acceptance_rate']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate', 'price', 'number_of_reviews',
#         'review_scores_rating'], dtype=object),
#  'n_features_in_': 4,
#  'coef_': array([ 5.00103565e-01, -1.69786068e-05,  1.62666347e-02,  2.88141425e+00]),
#  'rank_': 4,
#  'singular_': array([2.16083042e+06, 5.27710137e+03, 3.59116999e+03, 1.65804328e+02]),
#  'intercept_': 29.00913582625413}

# %% [markdown]
# Modelo matemático: y= 5.00103565e-01 x1 + -1.69786068e-05 x2 +  1.62666347e-02 x3 +  2.88141425e+00 x4 + 29.00913582625413

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.4062882379696482

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.4062882379696482

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.6374074348245776

# %% [markdown]
# ###"host_acceptance_rate vs host_response_rate, Price, number_of_reviews , review_scores_rating” F2

# %%
from turtle import color
sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=df_filtrado2)
sns.scatterplot(x='price', y='host_acceptance_rate', color="red", data=df_filtrado2)
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="yellow", data=df_filtrado2)
sns.scatterplot(x='review_scores_rating', y='host_acceptance_rate', color="green", data=df_filtrado2)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df_filtrado2[["host_response_rate", "price", "number_of_reviews" , "review_scores_rating"]]
Var_Dep= df_filtrado2['host_acceptance_rate']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate', 'price', 'number_of_reviews',
#         'review_scores_rating'], dtype=object),
#  'n_features_in_': 4,
#  'coef_': array([ 5.00103565e-01, -1.69786068e-05,  1.62666347e-02,  2.88141425e+00]),
#  'rank_': 4,
#  'singular_': array([2.16083042e+06, 5.27710137e+03, 3.59116999e+03, 1.65804328e+02]),
#  'intercept_': 29.00913582625413}

# %% [markdown]
# Modelo matemático: y= 5.00103565e-01 x1 + -1.69786068e-05 x2 +  1.62666347e-02 x3 +  2.88141425e+00 x4 + 29.00913582625413

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.4062882379696482

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.4062882379696482

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.6374074348245776

# %% [markdown]
# **### “Price” vs availability_365, host_response_rate, number_of_reviews, accommodates“ F1

# %%
sns.scatterplot(x='availability_365', y='price', color="green", data=df_filtrado1)
sns.scatterplot(x='host_response_rate', y='price', color="blue", data=df_filtrado1)
sns.scatterplot(x='number_of_reviews', y='price', color="yellow", data=df_filtrado1)
sns.scatterplot(x='accommodates', y='price', color="purple", data=df_filtrado1)
# Out:
# <Axes: xlabel='availability_365', ylabel='price'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df_filtrado1[["availability_365", "host_response_rate", "number_of_reviews", "accommodates"]]
Var_Dep= df_filtrado1['price']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['availability_365', 'host_response_rate', 'number_of_reviews',
#         'accommodates'], dtype=object),
#  'n_features_in_': 4,
#  'coef_': array([ -1.12035625,  -9.92598748,   2.9144699 , 298.15652833]),
#  'rank_': 4,
#  'singular_': array([11340.83955277,  5274.27499061,  3571.29844315,   125.77678238]),
#  'intercept_': 1854.1566456612945}

# %% [markdown]
# Modelo matemático: y= -1.12035625 x1 + -9.92598748 x2 +   2.9144699 x3 +  298.15652833 x4 + 1854.1566456612945

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.0006088975110930539

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.0006088975110930539

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.024675848741087993

# %% [markdown]
# ### “Price” vs availability_365, host_response_rate, number_of_reviews, accommodates“ F2

# %%
sns.scatterplot(x='availability_365', y='price', color="green", data=df_filtrado2)
sns.scatterplot(x='host_response_rate', y='price', color="blue", data=df_filtrado2)
sns.scatterplot(x='number_of_reviews', y='price', color="yellow", data=df_filtrado2)
sns.scatterplot(x='accommodates', y='price', color="purple", data=df_filtrado2)
# Out:
# <Axes: xlabel='availability_365', ylabel='price'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df_filtrado2[["availability_365", "host_response_rate", "number_of_reviews", "accommodates"]]
Var_Dep= df_filtrado2['price']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['availability_365', 'host_response_rate', 'number_of_reviews',
#         'accommodates'], dtype=object),
#  'n_features_in_': 4,
#  'coef_': array([ -1.12035625,  -9.92598748,   2.9144699 , 298.15652833]),
#  'rank_': 4,
#  'singular_': array([11340.83955277,  5274.27499061,  3571.29844315,   125.77678238]),
#  'intercept_': 1854.1566456612945}

# %% [markdown]
# Modelo matemático: y= -1.12035625 x1 + -9.92598748 x2 +   2.9144699 x3 +  298.15652833 x4 + 1854.1566456612945

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.0006088975110930539

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.0006088975110930539

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.024675848741087993

# %% [markdown]
# ### “host_acceptance_rate vs number_of_reviews,review_scores_cleanliness,review_scores_communication” F1

# %%
sns.scatterplot(x='review_scores_cleanliness', y='host_acceptance_rate', color="green", data=df_filtrado1)
sns.scatterplot(x='review_scores_communication', y='host_acceptance_rate', color="blue", data=df_filtrado1)
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="yellow", data=df_filtrado1)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df_filtrado1[["number_of_reviews","review_scores_cleanliness","review_scores_communication"]]
Var_Dep= df_filtrado1['host_acceptance_rate']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews', 'review_scores_cleanliness',
#         'review_scores_communication'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([0.04541775, 4.06614456, 2.38525702]),
#  'rank_': 3,
#  'singular_': array([5204.06394971,  249.88934365,   21.11011122]),
#  'intercept_': 52.30768774929481}

# %% [markdown]
# Modelo matemático: y= 0.04541775 x1 + 4.06614456 x2 + 2.38525702 x3 + 52.30768774929481

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.14298700551364285

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.14298700551364285

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.37813622613238584

# %% [markdown]
# ### “host_acceptance_rate vs number_of_reviews,review_scores_cleanliness,review_scores_communication” F1

# %%
sns.scatterplot(x='review_scores_cleanliness', y='host_acceptance_rate', color="green", data=df_filtrado2)
sns.scatterplot(x='review_scores_communication', y='host_acceptance_rate', color="blue", data=df_filtrado2)
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="yellow", data=df_filtrado2)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df_filtrado2[["number_of_reviews","review_scores_cleanliness","review_scores_communication"]]
Var_Dep= df_filtrado2['host_acceptance_rate']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews', 'review_scores_cleanliness',
#         'review_scores_communication'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([0.04541775, 4.06614456, 2.38525702]),
#  'rank_': 3,
#  'singular_': array([5204.06394971,  249.88934365,   21.11011122]),
#  'intercept_': 52.30768774929481}

# %% [markdown]
# Modelo matemático: y= 0.04541775 x1 + 4.06614456 x2 + 2.38525702 x3 + 52.30768774929481

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.14298700551364285

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.14298700551364285

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.37813622613238584

# %% [markdown]
# # California EU

# %%
# declaramos nuestros dataframes
dfc=pd.read_excel("Callimpio.xlsx")

# %%
fprivate = dfc['room_type'].str.contains('Private room')
df_filtrado1 = dfc[fprivate]

fhotel = dfc['room_type'].str.contains('Hotel room')
df_filtrado2 = dfc[fprivate]

# %% [markdown]
# ###"host_acceptance_rate vs host_response_rate, Price, number_of_reviews , review_scores_rating” F1

# %%
from turtle import color
sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=df_filtrado1)
sns.scatterplot(x='price', y='host_acceptance_rate', color="red", data=df_filtrado1)
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="yellow", data=df_filtrado1)
sns.scatterplot(x='review_scores_rating', y='host_acceptance_rate', color="green", data=df_filtrado1)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df_filtrado1[["host_response_rate", "price", "number_of_reviews" , "review_scores_rating"]]
Var_Dep= df_filtrado1['host_acceptance_rate']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate', 'price', 'number_of_reviews',
#         'review_scores_rating'], dtype=object),
#  'n_features_in_': 4,
#  'coef_': array([ 7.23041847e-01,  3.17204236e-06,  3.11656130e-04, -2.87797383e-02]),
#  'rank_': 4,
#  'singular_': array([9.72530727e+04, 4.94906787e+03, 2.36777109e+01, 1.82480917e+01]),
#  'intercept_': 0.32165536098474623}

# %% [markdown]
# Modelo matemático: y= 7.23041847e-01 x1 + 3.17204236e-06x2 +  3.11656130e-04 x3 +  -2.87797383e-02 x4 + 0.32165536098474623

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.6048982748683568

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.6048982748683568

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.7777520651649578

# %% [markdown]
# ###"host_acceptance_rate vs host_response_rate, Price, number_of_reviews , review_scores_rating” F2

# %%
from turtle import color
sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=df_filtrado2)
sns.scatterplot(x='price', y='host_acceptance_rate', color="red", data=df_filtrado2)
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="yellow", data=df_filtrado2)
sns.scatterplot(x='review_scores_rating', y='host_acceptance_rate', color="green", data=df_filtrado2)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df_filtrado2[["host_response_rate", "price", "number_of_reviews" , "review_scores_rating"]]
Var_Dep= df_filtrado2['host_acceptance_rate']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate', 'price', 'number_of_reviews',
#         'review_scores_rating'], dtype=object),
#  'n_features_in_': 4,
#  'coef_': array([ 7.23041847e-01,  3.17204236e-06,  3.11656130e-04, -2.87797383e-02]),
#  'rank_': 4,
#  'singular_': array([9.72530727e+04, 4.94906787e+03, 2.36777109e+01, 1.82480917e+01]),
#  'intercept_': 0.32165536098474623}

# %% [markdown]
# Modelo matemático: y= 7.23041847e-01 x1 + 3.17204236e-06 x2 +  3.11656130e-04 x3 +  -2.87797383e-02 x4 + 0.32165536098474623

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.6048982748683568

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.6048982748683568

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.7777520651649578

# %% [markdown]
# ### “Price” vs availability_365, host_response_rate, number_of_reviews, accommodates“ F1

# %%
sns.scatterplot(x='availability_365', y='price', color="green", data=df_filtrado1)
sns.scatterplot(x='host_response_rate', y='price', color="blue", data=df_filtrado1)
sns.scatterplot(x='number_of_reviews', y='price', color="yellow", data=df_filtrado1)
sns.scatterplot(x='accommodates', y='price', color="purple", data=df_filtrado1)
# Out:
# <Axes: xlabel='availability_365', ylabel='price'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df_filtrado1[["availability_365", "host_response_rate", "number_of_reviews", "accommodates"]]
Var_Dep= df_filtrado1['price']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['availability_365', 'host_response_rate', 'number_of_reviews',
#         'accommodates'], dtype=object),
#  'n_features_in_': 4,
#  'coef_': array([   0.37449276, -284.6573589 ,   -1.34962041,  213.12536151]),
#  'rank_': 4,
#  'singular_': array([6569.11214239, 4963.9114323 ,   64.64482961,   18.03531766]),
#  'intercept_': 186.80212874366015}

# %% [markdown]
# Modelo matemático: y= 0.37449276x1 + -284.6573589x2 +   -1.34962041 x3 +  213.12536151 x4 + 186.80212874366015

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.027626156491513565

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.027626156491513565

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.16621118040466942

# %% [markdown]
# ### “Price” vs availability_365, host_response_rate, number_of_reviews, accommodates“ F2

# %%
sns.scatterplot(x='availability_365', y='price', color="green", data=df_filtrado2)
sns.scatterplot(x='host_response_rate', y='price', color="blue", data=df_filtrado2)
sns.scatterplot(x='number_of_reviews', y='price', color="yellow", data=df_filtrado2)
sns.scatterplot(x='accommodates', y='price', color="purple", data=df_filtrado2)
# Out:
# <Axes: xlabel='availability_365', ylabel='price'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df_filtrado2[["availability_365", "host_response_rate", "number_of_reviews", "accommodates"]]
Var_Dep= df_filtrado2['price']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['availability_365', 'host_response_rate', 'number_of_reviews',
#         'accommodates'], dtype=object),
#  'n_features_in_': 4,
#  'coef_': array([   0.37449276, -284.6573589 ,   -1.34962041,  213.12536151]),
#  'rank_': 4,
#  'singular_': array([6569.11214239, 4963.9114323 ,   64.64482961,   18.03531766]),
#  'intercept_': 186.80212874366015}

# %% [markdown]
# Modelo matemático: y= 0.37449276 x1 + -284.6573589  x2 +   -1.34962041 x3 +  298.15652833 x4 + 186.80212874366015

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.027626156491513565

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.027626156491513565

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.16621118040466942

# %% [markdown]
# ### “host_acceptance_rate vs number_of_reviews,review_scores_cleanliness,review_scores_communication” F1

# %%
sns.scatterplot(x='review_scores_cleanliness', y='host_acceptance_rate', color="green", data=df_filtrado1)
sns.scatterplot(x='review_scores_communication', y='host_acceptance_rate', color="blue", data=df_filtrado1)
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="yellow", data=df_filtrado1)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df_filtrado1[["number_of_reviews","review_scores_cleanliness","review_scores_communication"]]
Var_Dep= df_filtrado1['host_acceptance_rate']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews', 'review_scores_cleanliness',
#         'review_scores_communication'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([ 0.00078227,  0.00330653, -0.01864242]),
#  'rank_': 3,
#  'singular_': array([4963.93196404,   24.13852672,   11.51903486]),
#  'intercept_': 0.8048627865101142}

# %% [markdown]
# Modelo matemático: y=0.00078227 x1 + 0.00330653 x2 + -0.01864242 x3 + 0.8048627865101142

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.047857946541397633

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.047857946541397633

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.21876459160796025

# %% [markdown]
# ### “host_acceptance_rate vs number_of_reviews,review_scores_cleanliness,review_scores_communication” F2

# %%
sns.scatterplot(x='review_scores_cleanliness', y='host_acceptance_rate', color="green", data=df_filtrado2)
sns.scatterplot(x='review_scores_communication', y='host_acceptance_rate', color="blue", data=df_filtrado2)
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="yellow", data=df_filtrado2)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df_filtrado2[["number_of_reviews","review_scores_cleanliness","review_scores_communication"]]
Var_Dep= df_filtrado2['host_acceptance_rate']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#Verificamos los coeficientes obtenidos para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews', 'review_scores_cleanliness',
#         'review_scores_communication'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([ 0.00078227,  0.00330653, -0.01864242]),
#  'rank_': 3,
#  'singular_': array([4963.93196404,   24.13852672,   11.51903486]),
#  'intercept_': 0.8048627865101142}

# %% [markdown]
# Modelo matemático: y= 0.000782275 x1 + 0.00330653 x2 + -0.01864242 x3 + 0.8048627865101142

# %%
#Evaluamos la eficiencia del modelo obtenido por medio del coeficiente R Determinación
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.047857946541397633

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.047857946541397633

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.21876459160796025

# %% [markdown]
# # Girona Esp

# %%
# declaramos nuestros dataframes
dfe=pd.read_excel("Girona-limpio.xlsx")

# %%
fprivate = dfe['room_type'].str.contains('Private room')
df_filtrado_e = dfe[fprivate]

fhotel = dfe['room_type'].str.contains('Hotel room')
df_filtrado_e2 = dfe[fprivate]

# %% [markdown]
# ###"host_acceptance_rate vs host_response_rate, Price, number_of_reviews , review_scores_rating” F1

# %%
from turtle import color
sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=df_filtrado_e)
sns.scatterplot(x='price', y='host_acceptance_rate', color="red", data=df_filtrado_e)
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="yellow", data=df_filtrado_e)
sns.scatterplot(x='review_scores_rating', y='host_acceptance_rate', color="green", data=df_filtrado_e)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep= df_filtrado_e[["host_response_rate", "price", "number_of_reviews" , "review_scores_rating"]]
Var_Dep= df_filtrado_e['host_acceptance_rate']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate', 'price', 'number_of_reviews',
#         'review_scores_rating'], dtype=object),
#  'n_features_in_': 4,
#  'coef_': array([ 3.16101422e-01, -7.52072768e-05,  3.28398454e-04,  4.37135283e-02]),
#  'rank_': 4,
#  'singular_': array([1.81596392e+04, 2.18537880e+03, 1.51747760e+01, 1.45727865e+01]),
#  'intercept_': 0.3647104981875976}

# %% [markdown]
# Modelo matemático = 3.16101422e-01 x -7.52072768e-05 x2 + 3.28398454e-04 x3 + 4.37135283e-02 x4 + 0.3647104981875976

# %%
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.2086057605006042

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.2086057605006042

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.456733796100753

# %% [markdown]
# ###"host_acceptance_rate vs host_response_rate, Price, number_of_reviews , review_scores_rating” F2

# %%
from turtle import color
sns.scatterplot(x='host_response_rate', y='host_acceptance_rate', color="blue", data=df_filtrado_e2)
sns.scatterplot(x='price', y='host_acceptance_rate', color="red", data=df_filtrado_e2)
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="yellow", data=df_filtrado_e2)
sns.scatterplot(x='review_scores_rating', y='host_acceptance_rate', color="green", data=df_filtrado_e2)
# Out:
# <Axes: xlabel='host_response_rate', ylabel='host_acceptance_rate'>

# %%
Vars_Indep= df_filtrado_e2[["host_response_rate", "price", "number_of_reviews" , "review_scores_rating"]]
Var_Dep= df_filtrado_e2['host_acceptance_rate']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_response_rate', 'price', 'number_of_reviews',
#         'review_scores_rating'], dtype=object),
#  'n_features_in_': 4,
#  'coef_': array([ 3.16101422e-01, -7.52072768e-05,  3.28398454e-04,  4.37135283e-02]),
#  'rank_': 4,
#  'singular_': array([1.81596392e+04, 2.18537880e+03, 1.51747760e+01, 1.45727865e+01]),
#  'intercept_': 0.3647104981875976}

# %% [markdown]
# Modelo matemático = 3.16101422e-01 x1 - 7.52072768e-05 x2 + 3.28398454e-04 x3 + 4.37135283e-02 x4 + 0.3647104981875976

# %%
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.2086057605006042

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.2086057605006042

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.456733796100753

# %% [markdown]
# ### “Price” vs availability_365, host_response_rate, number_of_reviews, accommodates“ F1

# %%
sns.scatterplot(x='availability_365', y='price', color="green", data=df_filtrado_e)
sns.scatterplot(x='host_response_rate', y='price', color="blue", data=df_filtrado_e)
sns.scatterplot(x='number_of_reviews', y='price', color="yellow", data=df_filtrado_e)
sns.scatterplot(x='accommodates', y='price', color="purple", data=df_filtrado_e)
# Out:
# <Axes: xlabel='availability_365', ylabel='price'>

# %%
Vars_Indep= df_filtrado_e[["availability_365", "host_response_rate", "number_of_reviews", "accommodates"]]
Var_Dep= df_filtrado_e['price']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['availability_365', 'host_response_rate', 'number_of_reviews',
#         'accommodates'], dtype=object),
#  'n_features_in_': 4,
#  'coef_': array([  -0.40084556, -181.73711118,   -0.46210679,   14.24544114]),
#  'rank_': 4,
#  'singular_': array([4208.79622032, 2193.82634239,   63.63618814,   15.13071634]),
#  'intercept_': 355.95363769961466}

# %% [markdown]
# Modelo matemático = -0.40084556 x1 - 181.73711118 x2 - 0.4621067 x3 + 14.24544114 x4 + 355.95363769961466

# %%
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.04448776802545984

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.04448776802545984

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.21092123654449743

# %% [markdown]
# ### “Price” vs availability_365, host_response_rate, number_of_reviews, accommodates“ F2

# %%
sns.scatterplot(x='availability_365', y='price', color="green", data=df_filtrado_e2)
sns.scatterplot(x='host_response_rate', y='price', color="blue", data=df_filtrado_e2)
sns.scatterplot(x='number_of_reviews', y='price', color="yellow", data=df_filtrado_e2)
sns.scatterplot(x='accommodates', y='price', color="purple", data=df_filtrado_e2)
# Out:
# <Axes: xlabel='availability_365', ylabel='price'>

# %%
Vars_Indep= df_filtrado_e2[["availability_365", "host_response_rate", "number_of_reviews", "accommodates"]]
Var_Dep= df_filtrado_e2['price']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['availability_365', 'host_response_rate', 'number_of_reviews',
#         'accommodates'], dtype=object),
#  'n_features_in_': 4,
#  'coef_': array([  -0.40084556, -181.73711118,   -0.46210679,   14.24544114]),
#  'rank_': 4,
#  'singular_': array([4208.79622032, 2193.82634239,   63.63618814,   15.13071634]),
#  'intercept_': 355.95363769961466}

# %% [markdown]
# Modelo matemático: y= -0.40084556 x1 - 181.73711118 x2 -0.46210679 x3 + 14.24544114 x4 + 355.95363769961466

# %%
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.04448776802545984

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.04448776802545984

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.21092123654449743

# %% [markdown]
# ### “host_acceptance_rate vs number_of_reviews,review_scores_cleanliness,review_scores_communication” F1

# %%
sns.scatterplot(x='review_scores_cleanliness', y='host_acceptance_rate', color="green", data=df_filtrado_e)
sns.scatterplot(x='review_scores_communication', y='host_acceptance_rate', color="blue", data=df_filtrado_e)
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="yellow", data=df_filtrado_e)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='host_acceptance_rate'>

# %%
Vars_Indep= df_filtrado_e[["number_of_reviews","review_scores_cleanliness","review_scores_communication"]]
Var_Dep= df_filtrado_e['host_acceptance_rate']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews', 'review_scores_cleanliness',
#         'review_scores_communication'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([ 0.00079125,  0.11385336, -0.06083125]),
#  'rank_': 3,
#  'singular_': array([2193.83061534,   14.81156252,    8.02120217]),
#  'intercept_': 0.5176155341061273}

# %% [markdown]
# Modelo matemático: y= 0.00079125 x1 + 0.11385336 x2 -0.06083125 x3 + 0.5176155341061273

# %%
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.03282011581832678

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.03282011581832678

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.18116322976345609

# %% [markdown]
# ### “host_acceptance_rate vs number_of_reviews,review_scores_cleanliness,review_scores_communication” F2

# %%
sns.scatterplot(x='review_scores_cleanliness', y='host_acceptance_rate', color="green", data=df_filtrado_e2)
sns.scatterplot(x='review_scores_communication', y='host_acceptance_rate', color="blue", data=df_filtrado_e2)
sns.scatterplot(x='number_of_reviews', y='host_acceptance_rate', color="yellow", data=df_filtrado_e2)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='host_acceptance_rate'>

# %%
Vars_Indep= df_filtrado_e2[["number_of_reviews","review_scores_cleanliness","review_scores_communication"]]
Var_Dep= df_filtrado_e2['host_acceptance_rate']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
model.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['number_of_reviews', 'review_scores_cleanliness',
#         'review_scores_communication'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([ 0.00079125,  0.11385336, -0.06083125]),
#  'rank_': 3,
#  'singular_': array([2193.83061534,   14.81156252,    8.02120217]),
#  'intercept_': 0.5176155341061273}

# %% [markdown]
# Modelo matemático: y= 0.00079125 x1 + 0.11385336 x2 + -0.06083125 x3 + 0.5176155341061273

# %%
model.score(Vars_Indep,Var_Dep)
# Out:
# 0.03282011581832678

# %%
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.03282011581832678

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.18116322976345609
